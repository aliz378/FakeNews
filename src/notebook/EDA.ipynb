# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("/content/dataset.csv")
df = df.drop(['Unnamed: 0'], axis=1)
df.head(5)
# Out:
#                                            statement  \
# 0          Una cuenta de X (Twitter) publica vide...
# 1          Suplantan web de Red+ Noticias para se...
# 2          Ni Mario Fernández Alcocer anunció que...
# 3          La W no filtró este supuesto audio de ...
# 4          Este video no demuestra que ‘usarán la...
#
#                                  statement_paragraph  \
# 0          El video subido a X por ByViral24, en ...
# 1          El medio de comunicación no publicó la...
# 2          En una supuesta noticia, el candidato ...
# 3          En redes circula un video supuestament...
# 4          Se trata de una desinformación que cir...
#
#                                                links verdict
# 0  https://colombiacheck.com/chequeos/una-cuenta-...   Falso
# 1  https://colombiacheck.com/chequeos/suplantan-w...   Falso
# 2  https://colombiacheck.com/chequeos/ni-mario-fe...   Falso
# 3  https://colombiacheck.com/chequeos/la-w-no-fil...   Falso
# 4  https://colombiacheck.com/chequeos/este-video-...   Falso

# %%
df.isnull().sum()
# Out:
# statement              0
# statement_paragraph    0
# links                  0
# verdict                0
# dtype: int64

# %%
duplicate=df[df.duplicated()]
duplicate
# Out:
# Empty DataFrame
# Columns: [statement, statement_paragraph, links, verdict]
# Index: []

# %%
df.shape
# Out:
# (9954, 4)

# %%
df["verdict"].value_counts()
# Out:
# Falso                5955
# Cuestionable         2026
# Chequeo Múltiple      708
# Verdadero pero...     576
# Verdadero             410
# Podcast               177
# Inchequeable          102
# Name: verdict, dtype: int64
